# %%
import pandas as pd
import numpy as np
import os

# %%
# name of the variable in the sqf database file. 
# Notice that the NYPD uses different names for the same field 
# of the Stop and Frisk form from 2017 and on. 
year_variable = 'year'
precinct_variable = 'pct'
datestop_variable = 'datestop'
sus_crime_variable = 'crimsusp'
arst_made_variable = 'arstmade'
race_variable = 'race'

# %%
nypd_df_2014 = pd.read_csv('./data/sqf-2014.csv',  
                 usecols=[year_variable, precinct_variable, datestop_variable, 
                          sus_crime_variable, arst_made_variable, race_variable],
                 dtype={year_variable: int, precinct_variable:int, datestop_variable:int, 
                        sus_crime_variable:str, arst_made_variable:str, race_variable:str})
nypd_df_2015 = pd.read_csv('./data/sqf-2015.csv',
                 usecols=[year_variable, precinct_variable, datestop_variable, 
                          sus_crime_variable, arst_made_variable, race_variable],
                 dtype={year_variable: int, precinct_variable:int, datestop_variable:int, 
                        sus_crime_variable:str, arst_made_variable:str, race_variable:str})
nypd_df_2016 = pd.read_csv('./data/sqf-2016.csv',
                 usecols=[year_variable, precinct_variable, datestop_variable, 
                          sus_crime_variable, arst_made_variable, race_variable],
                 dtype={sus_crime_variable:str, arst_made_variable:str, race_variable:str})
nypd_df_2016 = nypd_df_2016.drop(12404)
nypd_df_2016.year = nypd_df_2016[year_variable].astype(int)
nypd_df_2016.pct = nypd_df_2016[precinct_variable].astype(int)
nypd_df_2016.datestop = nypd_df_2016[datestop_variable].astype(int)
# Out:
# C:\Users\maxpi\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2698: DtypeWarning: Columns (0,1,3) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
nypd_df_2016 = nypd_df_2016[nypd_df_2016[datestop_variable] < 4000000] # only consider stops up to march
nypd_df_2016[datestop_variable] = nypd_df_2016[datestop_variable] + 12000000 # modifies date of stop so that stops from 2015 through 2016 are continuous (months 1-15)
nypd_df = pd.concat((nypd_df_2015, nypd_df_2016))

# %%
# is n_ep specific to that type of crime?
# violent crimes
regex_string = '120|121|ASLT|OGA|MURDER|MENACING|HOMICIDE|RAPE|ENDANGER|FIGHT|ASAULT|ASSULT'
prev_arrsts_violent = nypd_df_2014[nypd_df_2014[sus_crime_variable].str.contains(regex_string, regex=True)]
stops_violent = nypd_df[nypd_df[sus_crime_variable].str.contains(regex_string, regex=True)]

# weapons crimes
regex_string = '265|CPW|CWP|GUNPOINT|FIREARM|WEAPON|C\.P\.W|CRIMINAL POSSESSION OF W|C/P/W '
prev_arrsts_weapons = nypd_df_2014[nypd_df_2014[sus_crime_variable].str.contains(regex_string, regex=True)]
stops_weapons = nypd_df[nypd_df[sus_crime_variable].str.contains(regex_string, regex=True)]

# property crimes
regex_string = '140|155|165|GLA|BURG|TRES|LFA|ROB|UUV|CT|LARC|MARIJ|HOME INVASION|ARSON|PROPERTY|PL|G\.L\.|GL|G/L|RONNERY|C/T|BURB'
prev_arrsts_prop = nypd_df_2014[nypd_df_2014[sus_crime_variable].str.contains(regex_string, regex=True)]
stops_prop = nypd_df[nypd_df[sus_crime_variable].str.contains(regex_string, regex=True)]

# drug crimes 
regex_string = '220|221|CPSP|CSCS|CPM|CSM|UPM|CPN|DRUG|CSCA'
prev_arrsts_drug = nypd_df_2014[nypd_df_2014[sus_crime_variable].str.contains(regex_string, regex=True)]
stops_drug = nypd_df[nypd_df[sus_crime_variable].str.contains(regex_string, regex=True)]

# %%
list(nypd_df[sus_crime_variable].unique())
# Out:
# ['FELONY',
#  'MISD',
#  'MIDS',
#  'FEL',
#  'FEONY',
#  'FELONY/ROBBERY',
#  'ROBBERY',
#  'ASSAULT',
#  'CPW FIREARM/ASSULAT 1',
#  'FELONY/CPW',
#  'GLA',
#  'CPW',
#  'MISDEMEANOR',
#  'MENACING W/FIREARM',
#  'FELONY ASSAULT',
#  'FEL/ROB',
#  'MIS/ASSAULT',
#  'PETIT LARCENY',
#  'GRAND LARCENY',
#  'ASLT',
#  'ROBBERY AT GUN POINT',
#  'PET LARC',
#  'POSSESSION OF WEAPON/FIR',
#  'MIS',
#  'COMM BURGS',
#  'ASSAULT 2',
#  'ASSAULT FELONY',
#  'F',
#  'BURG',
#  'MIS/CPW',
#  'MAKING GRAFFITI',
#  'UNAUTHORIZED USE',
#  'FEL  / ROBBERY',
#  'BURGLARY`',
#  'BURGLARY',
#  'CPW/ATTEMPED MURDER OF P',
#  'CPW/ATT MURDER OF PO',
#  'PETIT LARC',
#  'FEL/GLFA',
#  'GRAND LARCENY AUTO',
#  'CPCS',
#  'CRIMINAL TRESPASS',
#  'FEL/GLA',
#  'HOMICIDE',
#  'GLA (FEL)',
#  'M',
#  'FELONY/GLA',
#  'CRIMINAL MISCHIEF',
#  'CSCS',
#  'ASSAULT 3',
#  'ASSAULT  3',
#  'FEL  / GLA',
#  'CRIM TRESPASS',
#  'FEL/ATT ROBB',
#  'CRIM TRES/CPW',
#  'CPW/CRIM TRESS',
#  'BURGLARY / CPW',
#  'CPM',
#  'C.P.W.',
#  'MISDMEANOR',
#  'FORCIBLE TOUCHING',
#  'CRIMINAL ,MISCHIEF, GLA',
#  'CPSP',
#  'FEL/GL',
#  'PET LARC CROM AUTO',
#  'ROBBERY (FEL)',
#  'CRIM TRES',
#  'MIDEMEANOR',
#  'CPM / DRUG SALES',
#  'RESISTING ARREST',
#  'FLE / GLA',
#  'MIS/CRIM MIS',
#  'FEL/ROBB',
#  'CRIMINAL TREPASS',
#  'CRIMINAL TREPRASS',
#  'FELONY/BURGLARY',
#  'FELONY/BURG',
#  '155.30',
#  'GRAND LARCENY FROM AUTO',
#  'FEL  / CPW',
#  'FEL  / ROBBERY / CPW',
#  'CRIM TRESPASS/CPW',
#  'BURGALARY',
#  'MISDQ',
#  'COMM BURGLARY',
#  'PL FROM AUTO',
#  'COMM BURG',
#  'CRIMINALTRESPASS /CPCS',
#  'CPW/CPM',
#  'FELONY/GRAND LARCENY',
#  'ROBBERY / CPW',
#  'PETIT LARCENY/CPSP',
#  'G.L.',
#  'CRIM MISCHIEF',
#  'ROBB',
#  'C.P.W',
#  'CT',
#  'CPW / ROBBERY',
#  'CPCS 7',
#  'FEL  / CPW / ROBBERY',
#  'GL FROM AUTO',
#  'CPW / CRIMINAL TRESPASS',
#  'CRIMINALTREPASS',
#  'CPM / CPW',
#  'CPW/GLA',
#  'ASSAULT 2ND DEGREE',
#  'MISD/PUBLIC LEWDNESS',
#  'CRIMINAL MISC',
#  'GLA / CPSP - AUTO',
#  '1034',
#  'CPW-GUN RUN',
#  'CPW- GUN RUN',
#  'FRLONY',
#  'FEL/CPW',
#  'ROBBERY FELONY',
#  'FEL/GRAND LARCENY',
#  'FELONY-CPW',
#  'ASSAULT 1',
#  'ROBBERY PATTERN',
#  'CRIM TRESSPASS',
#  'AUTO STRIPPING',
#  'FEL  / BURGLARY',
#  'TRESPASS',
#  'ROBBERY FEL',
#  'CPCS-SALE',
#  'ROB',
#  'ENDANGERING THE WELFARE',
#  'FELON Y',
#  'PET LARCENY',
#  'PET LARCENY FROM AUTO',
#  'UUV LARCENY FROM AUTO',
#  'O.O.P VIOLATION',
#  'LARCENY',
#  'UUS/LARCENY FROM AUTO',
#  'TRESSPASS',
#  'GRAND LARCENY FELONY',
#  'GLA/ AUTO STRIPPING',
#  'POSSESSION OF FORGED INS',
#  'CPW (GUN)',
#  'PL AUTO',
#  'GUN CPW FELONY',
#  'CPW - FELONY (GUN)',
#  'CRIM. TRES',
#  'FEL / CPW',
#  'CPW FELONY',
#  'GRAND LARCENY  AUTO',
#  'LARCENY CAR BREAK',
#  'LARCENY FROM AUTO',
#  'FELONY-ROBBERY',
#  'G.L.A',
#  'CSCA',
#  'CPW-FIREARM',
#  'MISDEMEANOR ASSAULT',
#  'CRIMINAL TRESPASSING',
#  'ROBBERY / GRAND LARCENY',
#  'CPW GUN',
#  'CPW, CRIM TRESS',
#  'UUV',
#  'FEL/BURG',
#  'ROBBERY IN PROGRESS',
#  'CPW/ROB',
#  'GRAND LARC',
#  'PETIT LARCENY/AUTO BREAK',
#  'GRAND LARCENY (FEL)',
#  'CSCS, CSM',
#  'HARRASSMENT',
#  'MISD / PETIT LARCENY',
#  'UUV - LARCENY FROM AUTO',
#  'CRIM MIS',
#  'UNLAWFUL ASSEMBLY',
#  'MURDER',
#  'ASSAULT 2 FELONY',
#  'CRIMINALTRESPASS',
#  'GANG ASSAULT',
#  'UNAUTHORIZED SALE OF FAR',
#  'CWP',
#  'CPW / FIREARM',
#  'FEL  / CPW / ASSAULT',
#  'CPW / MENACING',
#  'CSCS/CPW',
#  'P LARCENY FROM AUTO',
#  'GLA / CPSP AUTO',
#  'CPCS / CPM',
#  'MISD/ASSAULT',
#  'CRIM POSS OF A WEAPON',
#  '220.39',
#  'SOLICITING PROSTITUTION',
#  'CPCS/CSCS',
#  'FEL/MISD',
#  'GRAFFITI',
#  '121.11',
#  'MISD/GRAFFITI',
#  'ATTP BURG',
#  'BURGLARY(COMMERCIAL)',
#  'VIOL',
#  'FELONYH',
#  'ROBBERY (RFEL)',
#  'ASSAULT / CPW',
#  '34 ASSAULT',
#  'PETIT LARCENY FROM AUTO',
#  'PL 160.15 SUB 2',
#  'CPW/ROBBERY',
#  'DWI',
#  'POSSESSION OF FIREARM',
#  'CRIMINAL CONTEMPT',
#  'MISD/ THEFT OF SERVICE',
#  'MISD / THEFT OF SERVICES',
#  'G/L',
#  'BURG/CPW',
#  'MISD/TOS',
#  'CRIM MISC.',
#  'PL 221.10',
#  'BURG(RESIDENTIAL)',
#  'CRIM MIS. GRAFFITI',
#  'CRIMINAL MISCHIEF GRAFFI',
#  'COMM ROBBERY',
#  'CRIM POSS STOLEN PROPERT',
#  'IMPERSONATION OF POLICE',
#  'MIS/PETIT LARCENY',
#  'TRESPASSING',
#  'PARK AFTER DARK/TRESPASS',
#  'CRFIMINAL TRESPASS',
#  'OLD POST',
#  'ASAULT',
#  'MISD/FEL',
#  'CRIMINAL POSS. OF CONTRO',
#  'FELONY/ASSAULT',
#  'FEK',
#  'CRIM CONTEMPT',
#  'MISD / 221.10 CRIM POS M',
#  'ASSAULT/CRIM MISCHIEF',
#  'ROBBERY/CPW',
#  'GLA / CPSP',
#  '140.20',
#  'FEL  / G.L.A.',
#  'HARASSMENT',
#  'CPW  CPM',
#  'TERRORIST ACTIVITY',
#  'ASSUALT 3',
#  'CRIM IMPERSONTATION',
#  'STALKING',
#  'RONNERY',
#  '265.03',
#  'MISD / CRIM TRESS',
#  'I CARD ROB',
#  'ASSAULT`',
#  'SUSPECTED BURGLARY',
#  'MENACING',
#  'CRIM TRESS',
#  'LARC FROM AUTO',
#  'FEL/ASSAULT',
#  'BURB',
#  'UPM',
#  'CPM/CRIMINAL TRESP',
#  'C/T',
#  'FEL  / GRAND LARCENY',
#  'RECLESS ENDANGERMENT/CPW',
#  'STOLEN LICENSE PLATE',
#  'GL',
#  'ROBBERY /BURGLARY',
#  'MIS/MENACING',
#  'FEL  / ASSAULT',
#  'TERRORISM',
#  'CRIM SALE CONT SUBSTANCE',
#  'ROBBERY 10-30',
#  'CPW  GUN',
#  'PATRONIZING PROSTITUTION',
#  'ASSUALT 2',
#  'FEL GLFA',
#  'MISD / CRIMINAL TRESS',
#  'BURGLARY (FEL)',
#  'MIS/CRIM TRESPASS',
#  'MIS/CRIM TRES',
#  'FEL/ROBBERY',
#  'HOMICIDE FROM 2/16/15',
#  'CRIM  TRES',
#  'CPM-SALE',
#  'FELNY',
#  'CRIMINAL TRESSPASS',
#  'GL/CPW',
#  'ASSAULT/CPW',
#  'FELONEY',
#  'CRIM POSSESSION OF MARIJ',
#  'DRUG SALES',
#  'AUTO BREAKS/GLA',
#  'ASSAULT INVESTIGATION',
#  '221.40',
#  'GLA/CPW',
#  'ASSAULT 2/CPW',
#  'CSM',
#  'AUTO BREAKS/CPW',
#  'MISD GRAFFITI',
#  'FELOMY',
#  'FELONE',
#  'CPW-GUN',
#  'CPM 5',
#  'SEXUAL ASSAULT',
#  'CRIMINAL MIS.',
#  'MIS ASSAULT',
#  'NARCO SALES',
#  '155 GLA',
#  'PETIT LARCENY(AUTO)',
#  'CRIMINAL TRESSPAS',
#  'CRIMINAL TRESPASS AND CP',
#  'FEL/FORGERY',
#  'FEL / FORGERY',
#  'CPW / ASSAULT',
#  'FEL.GLA',
#  'MISD/PETIT LARC',
#  'CRIM MIS - AUTO',
#  'CPW / FELONY',
#  'CPW (FIREARM)',
#  'CPSP/BURGLARY',
#  'FEL/ TRESPASS',
#  'CRIMINAL TRESPASS (MISD)',
#  'GRAND LARCENYE',
#  'MID',
#  'BURG.',
#  'FELONLY',
#  'CRIM POSS OF WEAPON',
#  'CPSP/ LARCENY',
#  'ATTEMPTED KIDNAPPING',
#  'CW GRAND LARCENY PATH#5',
#  'GRLA',
#  'GLA/CPSP-AUTO',
#  'FELONHY',
#  'THEFT OF SERVICES',
#  'GLA/ CRIM MIS',
#  'CRIMINAL TRES',
#  'FELONIOUS ASSAULT',
#  'HOMICIDE-FELONY',
#  'CRIMINAL POSSESSION OF W',
#  'CPSP  PL 165.40',
#  'ASSAULT MISD',
#  'CRM TRESPASS',
#  'RAPE',
#  'CPW/MENACING',
#  'GLA  / CPSP',
#  'UUV / LARCENY FROM AUTO',
#  'GLA/CPSP',
#  'GELONY/GLA',
#  'TRESPASS-CRIM',
#  'FELO NY',
#  'MISSING',
#  'MIS/ANIMAL CRUELTY',
#  'MIS/PUBLIC LEWDNESS',
#  '155.25',
#  'FELONY/HOME INVASION',
#  'ASSAULT I-CARD / WARRANT',
#  '10-10 SHOTS FIRED/CPW',
#  'CPW - FIREARM',
#  'FELOMY/GRAND LARCENY',
#  'ASSAULT 2 (KNIFE)',
#  'CPW-FELONY',
#  'IMPERSONATION OF OFFICER',
#  'STRAGULATION',
#  'CRMIMINAL TRESPASS',
#  'ROBBERY 2',
#  'BURG/ GRAFFITI',
#  'FE;',
#  'BURGLARY/RAPE',
#  'CPW / HOMICIDE',
#  'CPW FIREARM',
#  'FELOMY/CPW',
#  'FELONY/CSM',
#  'FEL0NY/CSM',
#  'OPEN WARRANT FOR ROBBERY',
#  'GUNPOINT ROBBERY',
#  'BURGLARY, GRAND LARCENY',
#  'FELONY/GANG ASSAULT',
#  'MIS/ASSSAULT',
#  'FRAUDULANT ACCOSTING',
#  'ROBBERY ATTEMPT',
#  'MIS/RECKLESS ENDANGERMENT',
#  'MISD-SWIPING 165.16',
#  'BURGLARY/GRAND LARCENY',
#  ' MISDEMEANOR',
#  'NARCOTICS SALE/CRIMINAL TRESSP',
#  'MISD . VOP CRIMINAL CONTEMPT',
#  'GLA / CAR BREAKING',
#  'MALE WITH GUN',
#  'CPCS, ROW',
#  'MIS/CPM',
#  'PUBLIC LEWDNESS',
#  'BURGLARY / GLA',
#  'THEFT OF SERVICE',
#  'FEL/CPM',
#  'RECKLESS ENDANGERMENT',
#  'CPW (SHOTS FIRED)',
#  'CPW  (SHOTS FIRED)',
#  'ROBERY',
#  'FEL/CPFI',
#  'CPW - GUN',
#  'CRIM  MIS',
#  'CPM/UPM',
#  'GLA / PETIT LARCENY',
#  'MISDEANOR',
#  'CPW FIRE ARM',
#  'GRAND LARCEY',
#  'GLA UUV',
#  'ROBBERY W/GUN',
#  'ROBBERY W/ GUN',
#  'CPW F',
#  'CPW/SHOTS FIRED',
#  'CPCS CPM',
#  '221.40 MISD',
#  'PROMOTING GAMBLING',
#  'TRESSPASSING',
#  'CPW , FIREARM',
#  'MISEMEANOR',
#  'CPCS & CPM',
#  'CRIMINTAL TRESPASS',
#  'TRES PASSING, CRIMINAL',
#  'CSCS FEL',
#  'FALSE PERSONATION',
#  'GRAND LARC FROM AUTO',
#  'MSID',
#  'ROBBERY/FEL',
#  'ASSAULT 2`',
#  'MISD/CPM',
#  'ENDANGERING WELFARE OF A CHILD',
#  'MISD- 165.16 SWIPING',
#  'CT, CPM',
#  'CRIM TRESP',
#  'CRIMINAL POSSESSION  OF STOLEN',
#  'FE',
#  'CPW/ASSAULT',
#  'FEL/MURDER',
#  'GUN',
#  'GLA / CPSP MOTORCYCLE',
#  'GLA / CPSP - MOTORCYCLE',
#  'FELD',
#  'CPW/ROBBERY/CPM',
#  'CPW/MISD',
#  'BRUGLARY (FEL)',
#  'CSCS (FELONY)',
#  'CSCS  (FELONY)',
#  'ASSAULT-FELONY',
#  'CRIM. TRESPASS',
#  'SUSPECTED TERRORISM',
#  'FELONY/CRIM CONTEMPT',
#  'GRAND LARCENYY',
#  'MIISD',
#  'MENACED W/FIREARM',
#  'MISD/CRIM TRES',
#  'UNLAWFUL POSS OF FIREWORKS',
#  'UNLAWFUL POSSESSION OF FIREWOR',
#  'UNLAWFUL WEAR BULLETPROOF VEST',
#  'MISD/CSCS',
#  'ARSON',
#  'FEL./GLFA',
#  'CPM (MISD)',
#  'CPW (MISD)',
#  'UNLAWFUL SURVEILLANCE',
#  'CRIMINAL MISCHIEF (VEHICLE)',
#  'GRAND LARCENY / CPW',
#  'AUTO STRIPPING / LARCENY',
#  'SEX ASSAULT',
#  'MISD/LARCENY',
#  'CPM5/CT',
#  'CPM5',
#  'CPW (KNIFE)',
#  'MISD  / CRIM MISCHIEF',
#  'FELONY/BURGLAY',
#  '265.01-CRIM POSS OF WEAPON 4TH',
#  'ASSAULT 3RD',
#  'FELO',
#  'MISD / CSCS',
#  'AUTO BREAK-IN / LARCENY',
#  'MISD / ASSAULT',
#  '140.10',
#  'HOMOCIDE',
#  'BURGLARY STREET',
#  'MVA FATAL LEFT SCENE',
#  'FED',
#  'GRAND LARCENY TIRES & RIMS',
#  '10-30 ROBBERY',
#  'MISD/CPW',
#  'CRIMINAL MIS/MAKEING GRAFITTI',
#  'LARCENY FROM VEHICLE',
#  'MISSD',
#  'GUN POSSESSION/CPW',
#  'ASSAULT (POSSIBLE)',
#  'MISD / CRIM. MIS',
#  'FE/GLA',
#  'MISD/RECKLESS ENDANGERMENT',
#  'FELONT/CPW',
#  'ASSAULT 2/GRAND LARCENY',
#  'UNAUTHORIZED USE OF VEHICLE',
#  'TOS',
#  'ROBBERY / BURG',
#  'CPW(GUN)',
#  'CPW / GUN',
#  'MISD/PETIT LARCENY',
#  'GRAND LARCENU (FEL)',
#  'GLA/CPSP - AUTO',
#  'PETIT LARCNEY',
#  'CPW/CSCS',
#  'FEL/CPCS',
#  'FELONY/HOMICIDE',
#  'CFRIMINAL TRESPASS',
#  'CPW KNIFE',
#  'MISDEMENOR',
#  'UNLAWFUL DEALING WITH FIREWORK',
#  'GRAND LARCENY AUTO - FELONY',
#  'CPW 2',
#  'UUMV',
#  'CRIMINAL POSSESSION OF WEAPON',
#  'CRIMINAL SALE CONTROLLED SUBST',
#  'FELONY(FIREARM)',
#  'GLA CPSP AUTO',
#  'CRMINAL TRESPASS',
#  'MISD/OTHER',
#  'PROSTITUTION',
#  'GLA / CPSP -AUTO',
#  'TRESPASS/GRAFFITI',
#  'RECKLESS DRIVING/CPW',
#  'CPW/CPM/CRIMINAL TRESPASS',
#  'CPW/CPM/CIMINAL TRESPASS',
#  'MISD/CSM',
#  'MISDEAMENOR',
#  'TRESPASS / CPM',
#  'RAPE 3',
#  'BURGLARY/CPSP',
#  'MISD.',
#  'ATTEMPTED BURGLARY',
#  'CRIM. POSS. OF CONTROLLED SUBS',
#  'CPFI',
#  'PL 170.20',
#  'CPM 5TH',
#  'GAMBLING',
#  'MISDEMEANOR-SWIPING 165.16',
#  'CPW/DIS CON',
#  ' MISD',
#  'CRIMINAL POSS. OF MARIJUANA',
#  'MURDER /CPW FIREARM',
#  'CPW AND RECKLESS ENDANGERMENT',
#  'GRAND LARCENY FROM VEHICLE',
#  'MISD/FORCIBLE TOUCHING',
#  'CRIM POSS STOLEN PROPERTY',
#  'AUTO BREAKS',
#  'CPM/CPW',
#  'GLF/AUTO',
#  'ROBBEREY',
#  'CPW/CPCS',
#  'FELONY/RECKLESS ENDANGERMENT',
#  'ASSAULT/ CPW',
#  'ASS3',
#  'ASSAULT & CPW',
#  'ASSAULT AND CPW',
#  'CPW / MARIJUANA',
#  'FELPNY',
#  'MAKING GRAFITTI',
#  'CPW, ASSAULT',
#  'CPW FIREARMS',
#  'FELONYU',
#  'CRIMINAL POOSSESSION OF WEAPON',
#  'CRIMINAL POSSESSION OF STOLEN',
#  'CPM/CT',
#  'MISDEMEANOR WEAPON',
#  'MISDEMEANOR/WEAPON',
#  'MISD WEAPON',
#  'ASSAULT (SHOOTING)',
#  'FELOMNY',
#  'CPW/MEANCING',
#  'CRIM SALE NARCO',
#  'MISDEMEANOR-165.16 SWIPING',
#  'CRIMINAL MISD',
#  'MISDEMEANOR- MTA IMPERSONATION',
#  'OGA',
#  'MISD/MENACING',
#  'PL 265.03',
#  'MISDEMEANER',
#  'CPW/FIREARM',
#  'ASSULT/MISD',
#  'FEL/CRIM TRESPASS',
#  'GLA/ROBBERY',
#  'ROBBERY-ARMED',
#  'FELONY/LARCENY',
#  'FELINY',
#  'CAR BURGLARY',
#  'PROMOTE GAMBLING',
#  'ASAULT 3',
#  'RESISTING',
#  'CPW (F)',
#  'CPM,CPN',
#  'CPN,CPM',
#  'BURGLARY (FFEL)',
#  '(10-32) PETIT LARCENY',
#  'MISD/ASSAULT 3',
#  'MIS/LARCENY',
#  'ROBBERY/CPW/ASSAULT',
#  'PETIT LARCENCY',
#  'PETIT LACENY',
#  'PETIT',
#  'CPW / AUTO STRIPPING',
#  'CPW /AUTO STRIPPING',
#  'FELONY OF FIREARM',
#  'ASSAULT-3',
#  'KIDNAPPING',
#  'ASSAULT, CPW',
#  'FIREWORKS',
#  'CPW- FIREARM',
#  'CPW GLA',
#  'CRIM CONT SUB',
#  'PETIT  LARC',
#  'PETIT LARCENY (MISD)',
#  'CRIM POSS OF A WEAPON, FIREARM',
#  'ROBBREY',
#  'BURG/GLA',
#  'CPW    (FELONY)',
#  'P LATRCENY FROM AUTO',
#  'CRIM MISC/GLA',
#  'CRIMINAL MISCH',
#  'ATT ROBBERY/FIREARM',
#  'CP,',
#  'PL 220.39',
#  'CPCS:CPW',
#  ' ROBBERY',
#  'GURGLARY',
#  'FEL/BURGLARY',
#  'CRIM MIS/GLA',
#  'CPW 4',
#  'FLE',
#  'ASSAULT ON POLICE OFFICER',
#  'CRIMINAL POSSESSION OF MARIJUA',
#  'TOS / 165.15',
#  'GUN POINT ROBBERY',
#  'UNLAWFUL USE FARE MEDIA',
#  'MISD/GLA',
#  'MMISD',
#  'MIUS/CPW',
#  'ASSAULT 1/CPW',
#  'MIS/GRAFFITI',
#  'ROBB / CPW',
#  'CRIM MIS/GRAFFITI',
#  'CPW/OGA',
#  'CPW (KNIFE/MACE)',
#  'ASSAULT W/KNIFE',
#  'VEHICULAR ASSAULT',
#  'FELONY CPW',
#  'SEXUAL MISCONDUCT',
#  'CPW (MISDEMEANOR)',
#  'CPW/ASSAULT 2',
#  'LARCANY',
#  'CRIMINAL MISCHIEFT',
#  'MIS/AUTO STRIPPING',
#  'PL.220.31 CRIM.SALE OF CONSUB',
#  'FELON',
#  'DRUG PARAPHRENLIA',
#  'GLA/LARCENY FROM AUTO',
#  '221.05',
#  'GLA/CPCS',
#  'GRAND L;ARCENY',
#  'DRUG SALE POSSIBLE WEAPON',
#  'CRIMINAL TAMP',
#  'GLA FROM AUTO',
#  'CPW  FIREARM',
#  '10-10 FIREARM',
#  'THEFTT OF SERVICE',
#  'CRIM. POSS. OF WEAPON',
#  'ROBBERY @ GUNPOINT',
#  'GLA/ CPSP',
#  'BURGLARYY',
#  'MARIHUANA CRIMINAL MISCHIEF',
#  'FEL/ROBBERY W/FIREARM',
#  'FEL/ROBB W/ FIREARM',
#  'MISD     CPM',
#  'CPW 265.01',
#  'CPW /KNIFE',
#  'MISD/CPSP',
#  'CRIM POSS MARIJUANA',
#  'ASSUALT 1 / CPW',
#  'MENACING/CPW',
#  'BURGLARY/ASSAULT',
#  'CPW, RECKLESS ENDANGERMENT',
#  'ATTEMPTED MURDER',
#  'CPW/SHOOTING',
#  'BURLGARY',
#  'UNAUTHORIZED USE OF A VEHICLE',
#  'MISD ASSAULT',
#  'FEL/ASLT',
#  'PL 140.10',
#  'UUV-LARCENY FROM AUTO',
#  'MISD/PLFA',
#  'GRANG LARCENY',
#  'LEAVING THE SCENE OF ACCIDENT',
#  'GLA/CPSP-AUTO`',
#  'CRIMINAL POSS OF WEAPON',
#  'FEL/G/L',
#  'MIDS/ CPW / STUN GUN',
#  'MISD / CPW / STUN GUN',
#  'CPW- GUN',
#  'MISDEMANOR',
#  'MISD -SWIPING 165.16',
#  'UNTAXED CIGARETTES',
#  'CRIMINAL MIS',
#  'GLA/CRIM POSS FORGED INS',
#  'CSM/CPM',
#  'ROBBBERY',
#  'CPW(FIREARM)',
#  'MISDEMEANOR PL 220.03 CPCS',
#  'RAPE 1',
#  'GRAND LARFCENY',
#  'AGGRAVATED HARASSMENT',
#  'GMABLING',
#  'MURDER CPW',
#  'FRAUD/ PETIT LARCENY',
#  'SHOTS FIRED',
#  'LARCENY FROM AUTO/CRIM MISCHIF',
#  'MIS/CPCS',
#  'RESIDENTIAL',
#  'ASSAULT- CPW',
#  'ASSAULT/SHOTS FIRED',
#  'CPW/ MENACING',
#  'OPEN AREST WARRANT',
#  'HARRASMENT 1',
#  'MISID',
#  'CRIMINAL TRESS.',
#  'UNK/10-85',
#  'MISDEMEANOR PETIT LARCENY',
#  'ASSAULT 3 / ROBBERY',
#  'SHOOTING',
#  'CRIM OB. BREATHE / MENACING',
#  'FELONY ROBBERY',
#  'CPCS/CPW',
#  'PETIT  LARCENY',
#  'TERRORISM/CPCS',
#  'PETIT LARCENY, CRIMINAL MISCHI',
#  ' CPW',
#  'INTENT TO SELL/DRUGS SALES',
#  'LARCENY / CPSP',
#  'CRIMINAL PERSONATION',
#  'GRAND LARCENY OF AUTO',
#  'FIREARM C/P/W',
#  'MIS/PETIT LARCENT',
#  'MISDEMNEAOR',
#  'P LARCENY',
#  'DRUG SALE CSCS',
#  'PROPOSED GAMBLING',
#  'FFELONY',
#  'CPM/CPCS',
#  'ASSAULT/WEAPON (F)',
#  'ASSAULT/ WEAPON',
#  'CRIMINAL SALE OF CONTROLLED SU',
#  'MISD 3',
#  'RECKLESS ENDAGERMENT',
#  'CRIMINAL MISCHIEG',
#  'GRAND LARCENY (FELONY)',
#  'CRIMINAL SALE OF MARIJUANA',
#  'GLA/ CPSP-AUTO',
#  'GLA/ CPSP AUTO',
#  'GLA/ CPSP- AUTO',
#  'FEL/CSM',
#  'SUTO DTRIPPING',
#  'BURGALRY',
#  '10-32 CAR BREAK IN',
#  '10-32 VEHICLE BREAK IN',
#  'PL 221.40',
#  'CPW (FELONY)',
#  'AUTO BREAK IN',
#  'FEOLONY',
#  'MISC',
#  'GLA/CPW/CPM',
#  'ASSSAULT',
#  'CRIMINAL POSS WEAPON',
#  '31 BURG',
#  'PHISICAL FIGHT',
#  'PHYSICAL FIGHT',
#  'CRIM POSS OF MARIJUANA',
#  'FEL/HOMICIDE',
#  'MIS/CPWC',
#  'VEL',
#  'TRESSPASS/CPM',
#  'CPM,',
#  'ROBBRY',
#  'GLA/ AUTO BREAKS',
#  'POSSIBLE NARCO SALE',
#  'FEWL',
#  'ASSAULT MIS',
#  '10-31',
#  'ASSAULT AND CPW TO MOS',
#  'UNLAWFULL POSS OF MARIJUANA',
#  'UNLAWFUL POSS MARIJUANA',
#  'ASSAULT (HATE CRIME)',
#  'ASSAULT  AND CPW TO MOS',
#  'GLA/CPSP-M-C',
#  'GLA/CPSP-MC',
#  'RECKLESS ENDANGERMENT / SHOTS',
#  'MENACING WITH WEAPON',
#  'RECKELESS ENDANGERMENT',
#  'COUNTERFEIT CURRENCY',
#  'COUNTIFEIT CURRENCY',
#  'CPW/CT',
#  'PETIT LARCENY/UUV',
#  'GLA/CPS',
#  'IMPERSONATING A POLICE OFFICER',
#  'FORGED INSTRUMENT',
#  'RECKLESS ENDANGERMENT/CPW',
#  'CRIMIANAL TRESPASS',
#  'SHOTS FIRED / CPW',
#  'ASSAULT/ ROBBERY',
#  'CPW / MEANCING',
#  'POSSIBLE FIREARM',
#  'CRIM TRESPASS/PETIT LARCENY',
#  'ASSAULT III    - P.L 120.00',
#  'POSS OF FIREARM',
#  '220.10',
#  'ROBEBRY',
#  'CRIM POSS WEAPON',
#  'GRAND LARECNY',
#  'GLA/MOTORVEHICLE CPSP',
#  'CRIMINAL MISHCIEF',
#  'CPW / KNIFE',
#  'MENACING, CPW',
#  'CPPM',
#  'CONSPIRACY/ CPW FIREARM',
#  'M,',
#  'CRIM POSS OF STOLEN PROPERTY',
#  'PL 160',
#  'MISDEMEANOR/CPSP',
#  'GL OF AUTO',
#  'CRIME CONTEMPT',
#  'CRIM. POSS OF STOLEN PROPERTY',
#  'GUN RUN',
#  '221,05',
#  'CRIMINAL SALE MARIJUANA',
#  'CRIMINAL POSSESSION OF A WEAPO',
#  'CRIM  TRESPASS',
#  'MSD',
#  'AUTO BREAK',
#  'CRIMINAL PSSESSION OF A WEAPON',
#  'MISD/CPCS',
#  'DRUG',
#  'WARRANT',
#  'CPW (GUN) MENACING',
#  'ATT GRAND LARCENY',
#  'ROBBERY / CPM',
#  'FLED',
#  'MSI',
#  'RECKLESSENDANGERMENT',
#  'MEANCING',
#  '221.10',
#  'ROBBERY/FIREARM',
#  'PROSTITUTING',
#  'CRIMINAL IMPERSONATION',
#  'FELONY FIREARM',
#  'CRIM POSS CONT. SUBS1/MONEY LN',
#  'FELONY/SHOOTING',
#  ' POSSESSION OF STOLEN PARTY',
#  '220.03',
#  '220.16',
#  'MI',
#  'CRIMINAL TRSPASS',
#  'GLA - CPSP AUTO',
#  'FELO9NY',
#  'FEL/ARSON',
#  'CRIMINAL POSSESSION MARIJUANA',
#  '34-52 W/KNIFE',
#  'CPM CPW',
#  'CPW   FELONY',
#  'MISD-SWIPING',
#  'CRIME TRESPASS',
#  'MED',
#  'ASSAULT W/WEAPON',
#  'GLA - CPSP - M.C.',
#  'GLA - CPSP',
#  'GLA - CPSP MOTORCYCLE',
#  'PETTIT LARCENY',
#  'CPM SALE',
#  'WANTED FOR ROBBERY',
#  'CRIMINAL TRESPASS/ ARSON',
#  'VIOLATION ORDER OF PROTECTION',
#  '265.01CPW',
#  '265.01 CPW',
#  '155.30 GRAND LARCENY',
#  '155.30 GRAND LARC',
#  'UUV / PETIT LARC FROM AUTO',
#  '2203',
#  'TRADEMARK COUNTERFEIT',
#  'PL.265',
#  'CPW/265',
#  'FELONY CSCS',
#  'CRIM TRESPASS / CPW',
#  'CPW/ ASSAULT',
#  'CSCS/CPC',
#  'CSCS/CPCS',
#  'CRIM-CONTEMPT',
#  'CPW  (FIREARM',
#  'MISDEAMOR',
#  'TRESPASS / CPW WALLET',
#  ' PETIT LARCENY',
#  'PETIT LARCENY (CAR BREAK-IN)',
#  'FELONY (CPW/ROBBERY)',
#  'POSSESSION OF FIREARM/SHOOTING',
#  'MIND',
#  'GUN RUN CPW',
#  'TERRORIST THREATS',
#  ' CRIMINAL TRESPASS',
#  'FELONY BURGLARS TOOLS',
#  'CRIMINAL TRESPASS/CPW',
#  'CRIMINAL POSS. OF WEAPON',
#  'CRIM RES.',
#  'CRIM TRES.',
#  'GLA / CPW',
#  'MISDEMENAOR',
#  'CRIM. POSS. FORGED INSTRUMENT',
#  'D.W.I.',
#  'CRIMINAL MISCHIEF/LARCENY MIS',
#  'CPM, CPW, CRIMINAL TRESPASS',
#  'CPM, CPW, CRIM TRESPASS',
#  'AGG HARASSMENT',
#  'CP',
#  'GRAFITTI',
#  'CRIMINAL TRESPASS/BURGLARY',
#  'ROBBERY W/FIREARM',
#  'CIMINAL SALE CONTROLLED SUB.',
#  'C/ MISCHIEF',
#  'SELLING SWIPES 165.16',
#  'CRIM POSS OF MARI',
#  'C.P.M',
#  'FIREARM - CPW',
#  'CPW/ARSON',
#  '10-11 COMMERCIAL BURGLARY',
#  'PETIT LARCENY`',
#  'MISD - GLA',
#  'FEL SHOTS FIRED',
#  'FEL (SHOTS FIRED)',
#  '10-10 FIREARM CPW',
#  'POSSESION OF FIREARM',
#  'CPW  / ROBB',
#  'GLA/CRIM MIS',
#  'COMMERCIAL ROBBERY',
#  '165.15(3) MISD',
#  'ROB/CPW',
#  'CPW/CRIMINAL TRESPASS',
#  'PL 120.00 ASLT',
#  'COMMERCIAL BURGLARY',
#  'CPW - LOADED FIREARM',
#  'ROB - FEL',
#  'POSS FORG INST. 170.25',
#  'ASSAULT 3RD DEGREE MISDEMEANO',
#  'BANK ROBBERY-FEL',
#  'UNLAWFUL POSSESION OF MARIJUA',
#  '160.15 ROBBERY',
#  'ROBBERY,CPW',
#  'CRIMINAL IMPERSONATION OF A P',
#  'UNAUTH. USE OF A VEHICLE',
#  'PARKING LOT',
#  'ABDUCTION',
#  'CRIMINAL SALE',
#  'ASSAULT 3RD(MISD)',
#  'CRIM TRESPSS',
#  'MISEDEMANOR',
#  'CPW, CRIMINAL TRESPASS',
#  'CPW - FEL',
#  'ROBBER',
#  'UNAUTHORIZED RECORDING/PHOTOS',
#  'AGG HAR - MISD',
#  'PAST BURGLARY',
#  'BURGLARY-FEL',
#  'ASSAULT W/WPN',
#  'CIMINAL TRESSPASS',
#  'CRIMINAL POSS OF FIREARM',
#  'ROBBERY-FEL',
#  'FELM',
#  'STREET',
#  'FELONY CPW FIREARM',
#  'FELONY6',
#  'ASSAUL',
#  'ROBBERY/CRIMINAL TRESPASS',
#  'CRIMINAL TRESPASS/ROBBERY',
#  ' FELONY',
#  'GRAND LARCENY ATTEMPTED  (FEL',
#  'GRAND LARCENY (ATTEMPTED)',
#  'ROBBERY`',
#  'FELONY MENACING FIREARM',
#  'SIDEWALK',
#  'CPW - MISD',
#  'MISDEMEANOR CRIM OBSTRUCT BRE',
#  'PL 220.31',
#  'PUBLIC LEWD',
#  'CPW, RECKLESS ENDORSEMENT',
#  'CPW/GUN',
#  'CPW/IMITATION PISTOL',
#  'CRIMINAL POSSESSION',
#  'BANK ROBBERY',
#  'LARCENY-FEL',
#  'GRAND LARCENY/ROBBERY',
#  'CPW/ ASSAULT 2',
#  'CRIMINAL POSS OF FORGED INST,',
#  'POSS ASSSAULT',
#  'ASSAULT 3/CRIMINAL MISCHIEF',
#  'CPW MISD',
#  'PL 215.15 FELONY CRIMINAL CON',
#  'CPW/ MENACING W/ WEAPON',
#  'CRIM SALE OF C.S',
#  'FELOINY',
#  'ROBBEY',
#  'CPW-MISD',
#  ...]

# %%
# types of crimes 
# violent 
# 120
# 121
# ASLT
# OGA
# MURDER
# MENACING
# HOMICIDE
# RAPE
# ENDANGER
# FIGHT
# string contains: 120|121|ASLT|OGA|MURDER|MENACING|HOMICIDE|RAPE|ENDANGER|FIGHT|ASAULT|ASSULT
# 
# weapons
# 265
# CPW
# CWP
# GUNPOINT
# FIREARM
# WEAPON
# string contains: 265|CPW|CWP|GUNPOINT|FIREARM|WEAPON|C.P.W|CRIMINAL POSSESSION OF W|C/P/W 

# property
# 140
# 155
# 165
# GLA
# BURG
# TRES
# GLFA
# ROB
# UUV
# CT
# LARC
# MARIJ
# PLFA
# ROBBERY
# HOME INVASION
# ARSON
# PROPERTY
# string contains: 140|155|165|GLA|BURG|TRES|LFA|ROB|UUV|CT|LARC|MARIJ|HOME INVASION|ARSON|PROPERTY|PL|G.L.|GL|G/L|RONNERY|C/T|BURB

# drugs
# 220
# 221
# CPSP
# CSCS
# CPM
# CSM
# UPM
# CPN
# DRUG
# string contains 220|221|CPSP|CSCS|CPM|CSM|UPM|CPN|DRUG|CSCA

#
# penal law reference: http://ypdcrime.com/penal.law/penal_law_title_m.htm
# 120 = assault and related offenses 
# 121 = strangulation and related offenses
# 140 = burglary and related offenses
# 155 = larceny
# 160 = robbery
# 165 = other offenses related to theft
# 170.20 = criminal posession of forged instrument
# 220 = possession of controlled substance
# 221 = possession of marijuana
# 265 = criminal possession of weapon/firearm

# Abbreviations 
# CPW = criminal posession of a weapon
# MISD/MIDS = misdemeanor 
# GLA = grand larceny auto
# ASLT = assault 
# BURG = burglary
# TRES = trespassing
# GLFA = grand larceny from auto?
# CPSP = criminal possession of stolen property
# CSCS = criminal sale of controlled substance
# CPM = criminal possession of marijuana
# ROB = robbery
# UUV = unauthorized use of vehicle 
# CSM = criminal sale of marijuana?
# CWP = concealed weapon?
# DWI = driving while intoxicated
# CT = criminal trespassing
# UPM = unlawful possession of marijuana?
# LARC = larceny
# MARIJ = marijuana
# TOS = theft of service
# OGA = obstruction of governmental administration
# CPN = criminal possession of narcotics
# PLFA = petit larceny from auto


# Synonyms/Typos 
# petit larceny: PET LARC, PL, 
# felony: FEL, FLE, FEK, FELNY, FELONEY, FELOMY, FELONHY, FELONYH, FELONLY, FELONE
# CPW: C.P.W, CRIMINAL POSSESSION OF W, C/P/W
# GLA: G.L., GL, G/L
# ASLT: ASAULT, ASSULT, 
# ROB: ROBBERY, RONNERY
# CT: C/T
# BURG: BURB
# CSCS: CSCA

# Miscellaneous observations
# ocurrence of "FELONHY" and "FELONYH"
# DRUG
# MURDER
# MENACING
# ROBBERY
# TRESPASS
# TERRORIST
# GRAND LARCENY
# HOMICIDE
# DRUG SALES
# RAPE
# HOME INVASION
# GUNPOINT
# CRIMINAL TRES
# FIREARM
# ENDANGER
# ARSON
# AUTO
# ENDANGERMENT
# LARCENY
# WEAPON
# FIGHT
# PROPERTY

# %%
# Race Values
# ref: https://static.prisonpolicy.org/scans/PRIMER_electronic_version.pdf
# W = white
# B = Black
# P = Black-Hispanic
# Q = White-Hispanic

# %%
nypd_df[race_variable].unique()
# Out:
# array(['W', 'B', 'Q', 'P', 'Z', 'A', 'I', 'U'], dtype=object)

# %%
precincts = nypd_df[precinct_variable].unique().tolist()
precincts.sort()

# %%
def process_arrests(prev_arrsts):
    
    study_races = set(['W', 'B', 'Q']) # races that we consider in the hierarchical models
    sqf_races = set(['W', 'B', 'Q', 'P']) # races in the sqf database that we're interested in 
    # W = White
    # B = Black
    # Q = White-Hispanic 
    # P = Black-Hipsanic
    sqf_to_study_map = {
        'W':'W',
        'B':'B',
        'Q':'Q',
        'P':'B'
    }
    
    arrsts_by_race = {}
    for race in study_races:
        next_dict = {precinct:0 for precinct in precincts}
        arrsts_by_race[race] = next_dict
    
    for race, pct, arstmade in zip(prev_arrsts[race_variable], prev_arrsts[precinct_variable], prev_arrsts[arst_made_variable]):
        if race in sqf_races and arstmade == 'Y':
            arrsts_by_race[sqf_to_study_map[race]][pct] += 1
    
    # Given the hierarchical models fit in Gelman's paper 
    # we replace any occurrences of 0 with 1 for the number
    # of arrests in the previous years
    for arrests_dict in arrsts_by_race.values():
        for precinct, num_arrsts in arrests_dict.items():
            if num_arrsts == 0:
                arrests_dict[precinct] = 1
        
    return arrsts_by_race

# %%
def process_stops(stops):
    
    study_races = set(['W', 'B', 'Q']) # races that we consider in the hierarchical models
    sqf_races = set(['W', 'B', 'Q', 'P']) # races in the sqf database that we're interested in 
    # W = White
    # B = Black
    # Q = White-Hispanic 
    # P = Black-Hipsanic
    sqf_to_study_map = {
        'W':'W',
        'B':'B',
        'Q':'Q',
        'P':'B'
    }
    
    stops_by_race = {}
    for race in study_races:
        next_dict = {precinct:0 for precinct in precincts}
        stops_by_race[race] = next_dict
    
    for race, pct, arstmade in zip(stops[race_variable], stops[precinct_variable], stops[arst_made_variable]):
        if race in sqf_races:
            stops_by_race[sqf_to_study_map[race]][pct] += 1
        
    return stops_by_race

# %%
pa_drug_by_race = process_arrests(prev_arrsts_drug)
pa_weapon_by_race = process_arrests(prev_arrsts_weapons)
pa_violent_by_race = process_arrests(prev_arrsts_violent)
pa_prop_by_race = process_arrests(prev_arrsts_prop)

stops_drug_by_race = process_stops(stops_drug)
stops_weapons_by_race = process_stops(stops_weapons)
stops_violent_by_race = process_stops(stops_violent)
stops_prop_by_race = process_stops(stops_prop)

# %%
# read-in precinct census data
census_df_og = pd.read_csv('./data/NYC_precinct_census_2017.csv', delimiter=',')
census_df_og = census_df_og.drop(0) # drop column totals
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-15-f96ced3a808e> in <module>()
#       1 # read-in precinct census data
# ----> 2 census_df_og = pd.read_csv('./data/NYC_precinct_census_2017.csv', delimiter=',')
#       3 census_df_og = census_df_og.drop(0) # drop column totals
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# --> 685         return _read(filepath_or_buffer, kwds)
#     686
#     687     parser_f.__name__ = name
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     455
#     456     # Create the parser.
# --> 457     parser = TextFileReader(fp_or_buf, **kwds)
#     458
#     459     if chunksize or iterator:
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options["has_index_names"] = kwds["has_index_names"]
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1133     def _make_engine(self, engine="c"):
#    1134         if engine == "c":
# -> 1135             self._engine = CParserWrapper(self.f, **self.options)
#    1136         else:
#    1137             if engine == "python":
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1915         kwds["usecols"] = self.usecols
#    1916
# -> 1917         self._reader = parsers.TextReader(src, **kwds)
#    1918         self.unnamed_cols = self._reader.unnamed_cols
#    1919
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'./data/NYC_precinct_census_2017.csv' does not exist: b'./data/NYC_precinct_census_2017.csv'

# %%
# new data 
census_df = pd.read_csv('./data/NYC_BlockGroups_Police_Precincts_Hispanic_Pop.csv', delimiter=',')

# %%
for col in census_df.columns:
    print(col)
# Out:
# FIPS
# Police Precinct ID
# Ge0_Name
# Total Population
# Total Population: Not Hispanic or Latino
# Total Population: Not Hispanic or Latino: White Alone
# Total Population: Not Hispanic or Latino: Black or African American Alone
# Total Population: Not Hispanic or Latino: American Indian and Alaska Native Alone
# Total Population: Not Hispanic or Latino: Asian Alone
# Total Population: Not Hispanic or Latino: Native Hawaiian and Other Pacific Islander Alone
# Total Population: Not Hispanic or Latino: Some Other Race Alone
# Total Population: Not Hispanic or Latino: Two or More Races
# Total Population: Hispanic or Latino
# Total Population: Hispanic or Latino: White Alone
# Total Population: Hispanic or Latino: Black or African American Alone
# Total Population: Hispanic or Latino: American Indian and Alaska Native Alone
# Total Population: Hispanic or Latino: Asian Alone
# Total Population: Hispanic or Latino: Native Hawaiian and Other Pacific Islander Alone
# Total Population: Hispanic or Latino: Some Other Race Alone
# Total Population: Hispanic or Latino: Two or More Races

# %%
census_df.head()
# Out:
#            FIPS  Police Precinct ID  \
# 0  3.606100e+11                   1
# 1  3.606100e+11                   1
# 2  3.606100e+11                   1
# 3  3.606100e+11                   1
# 4  3.606100e+11                   1
#
#                                             Ge0_Name  Total Population  \
# 0  Block Group 1, Census Tract 1, New York County...                 0
# 1  Block Group 0, Census Tract 5, New York County...                 0
# 2  Block Group 1, Census Tract 5, New York County...                 0
# 3  Block Group 1, Census Tract 7, New York County...              8881
# 4  Block Group 0, Census Tract 9, New York County...                 0
#
#    Total Population: Not Hispanic or Latino  \
# 0                                         0
# 1                                         0
# 2                                         0
# 3                                      8436
# 4                                         0
#
#    Total Population: Not Hispanic or Latino: White Alone  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                               6343
# 4                                                  0
#
#    Total Population: Not Hispanic or Latino: Black or African American Alone  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                226
# 4                                                  0
#
#    Total Population: Not Hispanic or Latino: American Indian and Alaska Native Alone  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    Total Population: Not Hispanic or Latino: Asian Alone  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                               1648
# 4                                                  0
#
#    Total Population: Not Hispanic or Latino: Native Hawaiian and Other Pacific Islander Alone  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    Total Population: Not Hispanic or Latino: Some Other Race Alone  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                 57
# 4                                                  0
#
#    Total Population: Not Hispanic or Latino: Two or More Races  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                162
# 4                                                  0
#
#    Total Population: Hispanic or Latino  \
# 0                                     0
# 1                                     0
# 2                                     0
# 3                                   445
# 4                                     0
#
#    Total Population: Hispanic or Latino: White Alone  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                271
# 4                                                  0
#
#    Total Population: Hispanic or Latino: Black or African American Alone  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  4
# 4                                                  0
#
#    Total Population: Hispanic or Latino: American Indian and Alaska Native Alone  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    Total Population: Hispanic or Latino: Asian Alone  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    Total Population: Hispanic or Latino: Native Hawaiian and Other Pacific Islander Alone  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    Total Population: Hispanic or Latino: Some Other Race Alone  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                 76
# 4                                                  0
#
#    Total Population: Hispanic or Latino: Two or More Races
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                 94
# 4                                                  0

# %%
census_df = census_df[['Police Precinct ID', 
                       'Total Population: Not Hispanic or Latino: White Alone', 
                       'Total Population: Not Hispanic or Latino: Black or African American Alone',
                       'Total Population: Hispanic or Latino: White Alone',
                       'Total Population: Hispanic or Latino: Black or African American Alone']].copy()
census_df['Total Population: Black'] = census_df['Total Population: Not Hispanic or Latino: Black or African American Alone'] + census_df['Total Population: Hispanic or Latino: Black or African American Alone']
census_df.rename(columns={'Total Population: Not Hispanic or Latino: White Alone':'Total Population: White', 
                          'Total Population: Hispanic or Latino: White Alone':'Total Population: Hispanic'}, inplace=True)
census_df = census_df.drop(columns=['Total Population: Hispanic or Latino: Black or African American Alone', 
                                    'Total Population: Not Hispanic or Latino: Black or African American Alone'])

# %%
len(census_df['Police Precinct ID'].unique())
# Out:
# 77

# %%
census_df.head()
# Out:
#    Police Precinct ID  Total Population: White  Total Population: Hispanic  \
# 0                   1                        0                           0
# 1                   1                        0                           0
# 2                   1                        0                           0
# 3                   1                     6343                         271
# 4                   1                        0                           0
#
#    Total Population: Black
# 0                        0
# 1                        0
# 2                        0
# 3                      230
# 4                        0

# %%
census_df = census_df.groupby('Police Precinct ID', as_index=False).sum()
census_df['Total Population'] = census_df['Total Population: White'] + census_df['Total Population: Hispanic'] + census_df['Total Population: Black']

# %%
census_df.head()
# Out:
#    Police Precinct ID  Total Population: White  Total Population: Hispanic  \
# 0                   1                    51658                        3519
# 1                   5                    11221                        2962
# 2                   6                    49538                        2764
# 3                   7                    13334                        6517
# 4                   9                    39999                        7558
#
#    Total Population: Black  Total Population
# 0                     1909             57086
# 1                     3601             17784
# 2                     1334             53636
# 3                     4732             24583
# 4                     6311             53868

# %%
census_df_og.head()
# Out:
#    Precinct  Cnt_Precin  Sum_Total_  Sum_White  Sum_Black  Sum_Hispan
# 1         1          34       73428      51658       1802        4956
# 2         5          35       52118      11221       2682        5898
# 3         6          48       61397      49538       1302        3524
# 4         7          37       54851      13334       3960       18327
# 5         9          49       75570      39999       5648       17454

# %%
data = {
        'Precinct': precincts,
    
        'Population_Total': census_df['Total Population'],
        'Population_White': census_df['Total Population: White'],
        'Population_Black': census_df['Total Population: Black'],
        'Population_Hispanic': census_df['Total Population: Hispanic'],
    
        'White_Drug_Prev_Arrests': list(pa_drug_by_race['W'].values()),
        'Black_Drug_Prev_Arrests': list(pa_drug_by_race['B'].values()),
        'Hispanic_Drug_Prev_Arrests': list(pa_drug_by_race['Q'].values()),
    
        'White_Drug_Stops': list(stops_drug_by_race['W'].values()),
        'Black_Drug_Stops': list(stops_drug_by_race['B'].values()),
        'Hispanic_Drug_Stops': list(stops_drug_by_race['Q'].values()),
    
        'White_Weapon_Prev_Arrests': list(pa_weapon_by_race['W'].values()),
        'Black_Weapon_Prev_Arrests': list(pa_weapon_by_race['B'].values()),
        'Hispanic_Weapon_Prev_Arrests': list(pa_weapon_by_race['Q'].values()),
    
        'White_Weapon_Stops': list(stops_weapons_by_race['W'].values()),
        'Black_Weapon_Stops': list(stops_weapons_by_race['B'].values()),
        'Hispanic_Weapon_Stops': list(stops_weapons_by_race['Q'].values()),
    
        'White_Violent_Prev_Arrests': list(pa_violent_by_race['W'].values()),
        'Black_Violent_Prev_Arrests': list(pa_violent_by_race['B'].values()),
        'Hispanic_Violent_Prev_Arrests': list(pa_violent_by_race['Q'].values()),
    
        'White_Violent_Stops': list(stops_violent_by_race['W'].values()),
        'Black_Violent_Stops': list(stops_violent_by_race['B'].values()),
        'Hispanic_Violent_Stops': list(stops_violent_by_race['Q'].values()),
    
        'White_Property_Prev_Arrests': list(pa_prop_by_race['W'].values()),
        'Black_Property_Prev_Arrests': list(pa_prop_by_race['B'].values()),
        'Hispanic_Property_Prev_Arrests': list(pa_prop_by_race['Q'].values()),
    
        'White_Property_Stops': list(stops_prop_by_race['W'].values()),
        'Black_Property_Stops': list(stops_prop_by_race['B'].values()),
        'Hispanic_Property_Stops': list(stops_prop_by_race['Q'].values()),
        }
precinct_df = pd.DataFrame(data)

# %%
precinct_df.to_csv('./data/stop_and_frisk_data_by_precinct.csv', index=False)

# %%
# split precincts into each category 
# 0 = less than 10% black
# 1 = 10-40% black
# 2 = > 40% black
precinct_to_category = {}
for index, row in census_df.iterrows():
    percent_black = row['Total Population: Black']/row['Total Population']
    current_precinct = row['Police Precinct ID']
    if percent_black < 0.1:
        precinct_to_category[current_precinct] = 0
    elif percent_black <= 0.4:
        precinct_to_category[current_precinct] = 1
    else:
        precinct_to_category[current_precinct] = 2

# %%
# export each e set for each category

# in the case of y_ep, occurrences is the number of stops 
# in the case of n_ep, occurrences is the number of arrests
def precinct_dataframe(list_data):
    return pd.DataFrame(list_data, columns = ['Precinct', 'Ethnic_Comp_Cat', 'Race', 'Race_Int', 'Eth_Pop_In_Precinct', 'Occurrences']) 

def get_eth_pop(precinct, race):
    race_col = ''
    if race == 'W':
        race_col = 'Total Population: White'
    elif race == 'B':
        race_col = 'Total Population: Black'
    else:
        race_col = 'Total Population: Hispanic'
        
    return int(census_df[census_df['Police Precinct ID']==precinct][race_col])
    
def extract_3_cats(ep):
    list_data = []
    races = ['W', 'B', 'Q']
    race_int = {'W':1, 'B':2, 'Q':3}
    
    for precinct in precincts:
        next_added = [[precinct, precinct_to_category[precinct], race, race_int[race], get_eth_pop(precinct, race), ep[race][precinct]] for race in races]
        list_data.extend(next_added)
    
    return precinct_dataframe(list_data)
    
n_ep_weapon = extract_3_cats(pa_weapon_by_race)
n_ep_drug = extract_3_cats(pa_drug_by_race)
n_ep_prop = extract_3_cats(pa_prop_by_race)
n_ep_violent = extract_3_cats(pa_violent_by_race)

y_ep_weapon = extract_3_cats(stops_weapons_by_race)
y_ep_drug = extract_3_cats(stops_drug_by_race)
y_ep_prop = extract_3_cats(stops_prop_by_race)
y_ep_violent = extract_3_cats(stops_violent_by_race)

# %%
n_ep_weapon.to_csv('./2014_arrests_weapon.csv', index=False)
n_ep_drug.to_csv('./2014_arrests_drug.csv', index=False)
n_ep_prop.to_csv('./2014_arrests_prop.csv', index=False)
n_ep_violent.to_csv('./2014_arrests_violent.csv', index=False)

y_ep_weapon.to_csv('./20152016_stops_weapon.csv', index=False)
y_ep_drug.to_csv('./20152016_stops_drug.csv', index=False)
y_ep_prop.to_csv('./20152016_stops_prop.csv', index=False)
y_ep_violent.to_csv('./20152016_stops_violent.csv', index=False)

# %%
n_ep_weapon[n_ep_weapon['Ethnic_Comp_Cat']==0]
# Out:
#      Precinct  Ethnic_Comp_Cat Race  Race_Int  Eth_Pop_In_Precinct  \
# 0           1                0    W         1                51658
# 1           1                0    B         2                 1909
# 2           1                0    Q         3                 3519
# 6           6                0    W         1                49538
# 7           6                0    B         2                 1334
# ..        ...              ...  ...       ...                  ...
# 226       122                0    B         2                 4746
# 227       122                0    Q         3                13451
# 228       123                0    W         1                87356
# 229       123                0    B         2                 1074
# 230       123                0    Q         3                 8441
#
#      Occurrences
# 0              1
# 1              1
# 2              1
# 6              1
# 7              1
# ..           ...
# 226            1
# 227            1
# 228            1
# 229            1
# 230            1
#
# [66 rows x 6 columns]

# %%
y_ep_weapon[y_ep_weapon['Ethnic_Comp_Cat']==0]
# Out:
#      Precinct  Ethnic_Comp_Cat Race  Race_Int  Eth_Pop_In_Precinct  \
# 0           1                0    W         1                51658
# 1           1                0    B         2                 1909
# 2           1                0    Q         3                 3519
# 6           6                0    W         1                49538
# 7           6                0    B         2                 1334
# ..        ...              ...  ...       ...                  ...
# 226       122                0    B         2                 4746
# 227       122                0    Q         3                13451
# 228       123                0    W         1                87356
# 229       123                0    B         2                 1074
# 230       123                0    Q         3                 8441
#
#      Occurrences
# 0              1
# 1              3
# 2              0
# 6              0
# 7              2
# ..           ...
# 226            8
# 227            6
# 228            0
# 229            0
# 230            0
#
# [66 rows x 6 columns]
